# %%
import cv2
import numpy as np
from PIL import Image
from pathlib import Path
import sys
from google.colab.patches import cv2_imshow
#input
filename= 'blue_snt.png'
img=cv2.imread(filename)
print(img)
#name= filename[0:5]
#converting into grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#applying histogram equalization
equ_img = cv2.equalizeHist(gray_img)
cv2_imshow(equ_img)
#writing the output image file
cv2.imwrite('enhanced-'+name+'.jpg',equ_img)
# Out:
# [[[200  74  79]
#   [214  51  55]
#   [221  51  54]
#   ...
#   [196  18  16]
#   [194  18  18]
#   [176  19  22]]
#
#  [[206  36  39]
#   [222   5   6]
#   [235   2   7]
#   ...
#   [237   3   5]
#   [234   3   5]
#   [209   7  10]]
#
#  [[216  35  35]
#   [234   3   2]
#   [249   0   3]
#   ...
#   [251   1   2]
#   [247   1   3]
#   [219   5   9]]
#
#  ...
#
#  [[222  36  39]
#   [242   1   1]
#   [250   0   0]
#   ...
#   [252   0   1]
#   [249   1   2]
#   [222   5   8]]
#
#  [[214  36  40]
#   [232   3   2]
#   [241   2   1]
#   ...
#   [243   2   1]
#   [242   2   2]
#   [221   5   8]]
#
#  [[202  56  59]
#   [214  25  24]
#   [221  23  21]
#   ...
#   [215  11   8]
#   [214  11   9]
#   [191  13  14]]]
# <PIL.Image.Image image mode=L size=141x248 at 0x7FA3C47BE9D0>
# True
