# %%
#if the input argument is expected to be string then
#input_string = str(sys.argv[1])
import cv2
import numpy as np
blank = np.zeros((300,500,3), dtype=np.uint8)
from google.colab.patches import cv2_imshow
#import sys
#num = int(sys.argv[1])
num=int(input())
num1= num//10
num2=num%10
p00=[50,32]; p01=[110,32]; p02=[170,32]; p10=[50,90]; p11=[110,90]; p12=[170,90]; p20=[50,148]; p21=[110,148]; p22=[170,148]; p30=[50,206]; p31=[110,206]; p32=[170,206]; p40=[50,264]; p41=[110,264]; p42=[170,264]
#marked all the (3*5)=15 points possible needed to form the first number circles
if (num1==1): circles=[p01,p11,p21,p31,p41]
elif (num1==2): circles=[p00,p01,p02,p12,p22,p21,p20,p30,p40,p41,p42]
elif (num1==3): circles=[p00,p01,p02,p12,p22,p21,p20,p32,p40,p41,p42]
elif (num1==4): circles=[p00,p10,p20,p21,p02,p12,p22,p32,p42]
elif (num1==5): circles=[p02,p01,p00,p10,p20,p21,p22,p32,p42,p41,p40]
elif (num1==6): circles=[p02,p01,p00,p10,p20,p21,p22,p32,p42,p41,p40,p30]
elif (num1==7): circles=[p10,p00,p01,p02,p12,p22,p32,p42]
elif (num1==8): circles=[p00,p01,p02,p12,p22,p32,p42,p41,p40,p30,p20,p10,p21]
elif (num1==9): circles=[p00,p01,p02,p12,p22,p32,p42,p41,p40,p20,p10,p21]
elif (num1==0): circles= [p00,p01,p02,p12,p22,p32,p42,p41,p40,p30,p20,p10]
#wrote all the 10 digits possible at first place

for centre in circles: result=cv2.circle(blank, centre, 25, (255,255,255),-1)

p00=[330,32]; p01=[390,32]; p02=[455,32]; p10=[330,90]; p11=[390,90]; p12=[455,90]; p20=[330,148]; p21=[390,148]; p22=[455,148]; p30=[330,206]; p31=[390,206]; p32=[455,206]; p40=[330,264]; p41=[390,264]; p42=[455,264]
if (num2==1): circles=[p01,p11,p21,p31,p41]
elif (num2==2): circles=[p00,p01,p02,p12,p22,p21,p20,p30,p40,p41,p42]
elif (num2==3): circles=[p00,p01,p02,p12,p22,p21,p20,p32,p40,p41,p42]
elif (num2==4): circles=[p00,p10,p20,p21,p02,p12,p22,p32,p42]
elif (num2==5): circles=[p02,p01,p00,p10,p20,p21,p22,p32,p42,p41,p40]
elif (num2==6): circles=[p02,p01,p00,p10,p20,p21,p22,p32,p42,p41,p40,p30]
elif (num2==7): circles=[p10,p00,p01,p02,p12,p22,p32,p42]
elif (num2==8): circles=[p00,p01,p02,p12,p22,p32,p42,p41,p40,p30,p20,p10,p21]
elif (num2==9): circles=[p00,p01,p02,p12,p22,p32,p42,p41,p40,p20,p10,p21]
elif (num2==0): circles=[p00,p01,p02,p12,p22,p32,p42,p41,p40,p30,p20,p10]

for centre in circles: result=cv2.circle(blank, centre, 25, (255,255,255),-1)

cv2_imshow(result)
res=cv2.imwrite('dotmatrix.jpg',result)
# Out:
# 4
# <PIL.Image.Image image mode=RGB size=500x300>
