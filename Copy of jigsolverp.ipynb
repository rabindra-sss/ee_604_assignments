# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
#input
img=cv2.imread('jigsaw.jpg')

img1= img[0:200,0:190,[1,0,2]]
img2= img[200:410,0:190]
img2 = cv2.flip(img2, 0)
img[0:210,0:190]= img2
img[200:400,0:190]= img1
img3= img[150:330,515:700]
img3= cv2.flip(img3,1) 
img[150:330,515:700]= img3
img4= img[370:421,370:797]
img4= cv2.flip(img4,0)
img[370:421,370:797]= img4
img5=img[395:400,0:190]
img6=img[410:415,0:190]
img5_p=cv2.copyMakeBorder(img5,0,5,0,0,cv2.BORDER_REPLICATE) 
img6_p=cv2.copyMakeBorder(img6,5,0,0,0,cv2.BORDER_REPLICATE) 
img[395:405,0:190]=img5_p
img[405:415,0:190]=img6_p    

cv2.imwrite('jigsolved.jpg',img) #save image
# Out:
# <PIL.Image.Image image mode=RGB size=797x421 at 0x7F52363B5C10>
# True
